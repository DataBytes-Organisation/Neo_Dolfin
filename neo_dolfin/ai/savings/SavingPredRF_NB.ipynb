# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import SavingPredAIUtil as util

# %%
#read input file 
transfile = "../../static/data/modified_transactions_data.csv"
df = util.read_file(path = transfile )

# %%
#resample the DataFrame with daily frequency and forward-fill missing values
data= util.data_resample(df)
# Out:
# resampling done.. resting the index

# %%
# Split the data into train and test
train_data,test_data = util.train_testsplit(data,0.8)
print("train sample:\n", train_data.head(10))
print("test sample:\n", test_data.head(10))
# Out:
# train sample:
#  postDate
# 2021-12-10   -259.34
# 2021-12-11   -259.34
# 2021-12-12   -259.34
# 2021-12-13   -759.34
# 2021-12-14   -558.34
# 2021-12-15   -558.34
# 2021-12-16   -357.34
# 2021-12-17   -357.34
# 2021-12-18   -357.34
# 2021-12-19   -357.34
# Name: balance, dtype: float64
# test sample:
#  postDate
# 2023-04-05    6028.37
# 2023-04-06    6010.15
# 2023-04-07    5402.65
# 2023-04-08    5402.65
# 2023-04-09    5324.65
# 2023-04-10    5324.65
# 2023-04-11    5324.65
# 2023-04-12    5324.65
# 2023-04-13    4824.65
# 2023-04-14    5025.65
# Name: balance, dtype: float64

# %%
train_data.plot()
# Out:
# <Axes: xlabel='postDate'>
